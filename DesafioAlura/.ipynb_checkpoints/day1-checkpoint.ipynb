# %% [markdown]
# # DAY 1

# %% [markdown]
# ## RESPOSTA GPT

# %%
import requests

# URL da API
url = 'https://last-airbender-api.fly.dev/api/v1/characters'

try:
    # Realiza a requisição GET
    response = requests.get(url)
    response.raise_for_status()  # Verifica se houve erro na requisição

    # Converte a resposta para JSON
    data = response.json()

    # Imprime o corpo da resposta
    print(data)

except requests.exceptions.RequestException as e:
    print(f'Ocorreu um erro na requisição: {e}')
except ValueError:
    print('Erro ao decodificar a resposta JSON.')
# Out:
# [{'_id': '5cf5679a915ecad153ab6903', 'allies': ['Aang'], 'enemies': [], 'photoUrl': 'https://vignette.wikia.nocookie.net/avatar/images/f/f8/Chong.png/revision/latest?cb=20140127210142', 'name': 'Chong'}, {'_id': '5cf5679a915ecad153ab68d6', 'allies': ['Aang'], 'enemies': ['Zhao'], 'photoUrl': 'https://vignette.wikia.nocookie.net/avatar/images/0/0c/Chief.png/revision/latest?cb=20140122221730', 'name': 'Arnook', 'affiliation': 'Northern Water Tribe'}, {'_id': '5cf5679a915ecad153ab68d4', 'allies': ['Appa'], 'enemies': ['Fire Nation'], 'photoUrl': 'https://vignette.wikia.nocookie.net/avatar/images/b/be/Appa%27s_mother.png/revision/latest?cb=20130705194428', 'name': "Appa's mother", 'affiliation': 'Air Nomads'}, {'_id': '5cf5679a915ecad153ab68cd', 'allies': ['Tenzin'], 'enemies': ['Equalists'], 'photoUrl': 'https://vignette.wikia.nocookie.net/avatar/images/c/cd/Air_Acolyte_woman.png/revision/latest?cb=20140421100225', 'name': 'Air Acolyte woman', 'affiliation': ' Air Acolytes Air Temple Is
# ...

# %% [markdown]
# 🔍 Explicação
# <code>requests.get(url):</code> Envia uma requisição HTTP GET para a URL especificada.
#
# <code>response.raise_for_status():</code> Lança uma exceção se a requisição retornou um erro HTTP.
#
# <code>response.json():</code> Converte o conteúdo da resposta para um objeto Python (geralmente uma lista ou dicionário).
#
# 📌 Observações
# A API retorna, por padrão, 20 personagens por página. Para obter mais personagens ou navegar entre as páginas, você pode utilizar os parâmetros <code>perPage</code> e <code>page</code>. Por exemplo:
#
# url = 'https://last-airbender-api.fly.dev/api/v1/characters?perPage=50&page=2'
#
# Certifique-se de ter o módulo requests instalado. Caso não tenha, você pode instalá-lo usando o comando pip install requests.

# %% [markdown]
# ## RESPOSTA PROF

# %%
import json
import requests

def personagens():

    api_url = f'https://last-airbender-api.fly.dev/api/v1/characters'

    response = requests.get(api_url)

    print(json.dumps(response.json(), indent=4))

personagens()
# Out:
# [
#     {
#         "_id": "5cf5679a915ecad153ab6903",
#         "allies": [
#             "Aang"
#         ],
#         "enemies": [],
#         "photoUrl": "https://vignette.wikia.nocookie.net/avatar/images/f/f8/Chong.png/revision/latest?cb=20140127210142",
#         "name": "Chong"
#     },
#     {
#         "_id": "5cf5679a915ecad153ab68d6",
#         "allies": [
#             "Aang"
#         ],
#         "enemies": [
#             "Zhao"
#         ],
#         "photoUrl": "https://vignette.wikia.nocookie.net/avatar/images/0/0c/Chief.png/revision/latest?cb=20140122221730",
#         "name": "Arnook",
#         "affiliation": "Northern Water Tribe"
#     },
#     {
#         "_id": "5cf5679a915ecad153ab68d4",
#         "allies": [
#             "Appa"
#         ],
#         "enemies": [
#             "Fire Nation"
#         ],
#         "photoUrl": "https://vignette.wikia.nocookie.net/avatar/images/b/be/Appa%27s_mother.png/revision/latest?cb=20130705194428",
# ...

# %% [markdown]
# ## CÓDIGOS COMBINADOS

# %%
import json
import requests

def personagens():
    api_url = 'https://last-airbender-api.fly.dev/api/v1/characters'

    try:
        response = requests.get(api_url)
        response.raise_for_status()  # Verifica se houve erro na requisição

        data = response.json()
        print(json.dumps(data, indent=4))  # Saída formatada

    except requests.exceptions.RequestException as e:
        print(f'Ocorreu um erro na requisição: {e}')
    except ValueError:
        print('Erro ao decodificar a resposta JSON.')

personagens()
# Out:
# [
#     {
#         "_id": "5cf5679a915ecad153ab6903",
#         "allies": [
#             "Aang"
#         ],
#         "enemies": [],
#         "photoUrl": "https://vignette.wikia.nocookie.net/avatar/images/f/f8/Chong.png/revision/latest?cb=20140127210142",
#         "name": "Chong"
#     },
#     {
#         "_id": "5cf5679a915ecad153ab68d6",
#         "allies": [
#             "Aang"
#         ],
#         "enemies": [
#             "Zhao"
#         ],
#         "photoUrl": "https://vignette.wikia.nocookie.net/avatar/images/0/0c/Chief.png/revision/latest?cb=20140122221730",
#         "name": "Arnook",
#         "affiliation": "Northern Water Tribe"
#     },
#     {
#         "_id": "5cf5679a915ecad153ab68d4",
#         "allies": [
#             "Appa"
#         ],
#         "enemies": [
#             "Fire Nation"
#         ],
#         "photoUrl": "https://vignette.wikia.nocookie.net/avatar/images/b/be/Appa%27s_mother.png/revision/latest?cb=20130705194428",
# ...
